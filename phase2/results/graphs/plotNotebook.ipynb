# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []
z = []
x2 = []
y2 = []
z2 = []

x3 = []
y3 = []
z3 = []
x4 = []
y4 = []
z4 = []

x5 = []
y5 = []
z5 = []
x6 = []
y6 = []
z6 = []

with open('1_RM_READ.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(int(row[0]))
        y.append(int(row[1]))
        z.append(int(row[2]))
        
with open('M_RM_READ.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x2.append(int(row[0]))
        y2.append(int(row[1]))
        z2.append(int(row[2]))
        
with open('1_RM_WRITE.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x3.append(int(row[0]))
        y3.append(int(row[1]))
        z3.append(int(row[2]))
        
with open('M_RM_WRITE.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x4.append(int(row[0]))
        y4.append(int(row[1]))
        z4.append(int(row[2]))

with open('1_RM_RW.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x5.append(int(row[0]))
        y5.append(int(row[1]))
        z5.append(int(row[2]))
        
with open('M_RM_RW.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x6.append(int(row[0]))
        y6.append(int(row[1]))
        z6.append(int(row[2]))
        
plt.clf()
plt.plot(x,y, '-',label='1 RM Read')
plt.plot(x2,y2, '-',label='Multiple RM Read')
plt.plot(x3,y3, '-',label='1 RM Write')
plt.plot(x4,y4, '-',label='Multiple RM Write')
#plt.plot(x5,y5, '-',label='1 RM Read&Write')
#plt.plot(x6,y6, '-',label='Multiple RM Read&Write')
plt.xlim([0, 550])
plt.ylim([0, 20000])
plt.xlabel('no. of transactions per second')
plt.ylabel('RTT in micro-secs')
plt.title('RTT for either READ or WRITE operations')
plt.legend()
plt.legend(loc=1, prop={'size': 10})
plt.show()
#fig = plt.figure()
#fig.savefig('../readOps.png')

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []
z = []
x2 = []
y2 = []
z2 = []

with open('1_RM_WRITE.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(int(row[0]))
        y.append(int(row[1]))
        z.append(int(row[2]))
        
with open('M_RM_WRITE.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x2.append(int(row[0]))
        y2.append(int(row[1]))
        z2.append(int(row[2]))
        
plt.clf()
plt.plot(x,y, '-',label='1 RM')
plt.plot(x2,y2, '-',label='Multiple RM')
plt.xlim([0, 550])
plt.ylim([5000, 20000])
plt.xlabel('no. of transactions per second')
plt.ylabel('RTT in micro-secs')
plt.title('RTT for Write operations')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []
z = []
x2 = []
y2 = []
z2 = []

with open('1_RM_RW.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(int(row[0]))
        y.append(int(row[1]))
        z.append(int(row[2]))
        
with open('M_RM_RW.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x2.append(int(row[0]))
        y2.append(int(row[1]))
        z2.append(int(row[2]))
        
plt.clf()
plt.plot(x,y, '-',label='1 RM')
plt.plot(x2,y2, '-',label='Multiple RM')
plt.xlim([0, 550])
plt.ylim([10000, 110000])
plt.xlabel('no. of transactions per second')
plt.ylabel('RTT in micro-secs')
plt.title('RTT for Read & Write operations')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []
z = []
x2 = []
y2 = []
z2 = []

with open('1_RM_READ.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(int(row[0]))
        y.append(int(row[1]))
        z.append(int(row[2]))
        
with open('M_RM_READ.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x2.append(int(row[0]))
        y2.append(int(row[1]))
        z2.append(int(row[2]))
        
plt.clf()
plt.plot(x,z, '-',label='1 RM')
plt.plot(x2,z2, '-',label='Multiple RM')
plt.xlim([0, 550])
plt.ylim([0, 200])
plt.xlabel('no. of transactions per second')
plt.ylabel('iterations before crash')
plt.title('Successful iterations before crash (READ)')
plt.legend()
plt.show()
#fig = plt.figure()
#fig.savefig('../readOps.png')

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []
z = []
x2 = []
y2 = []
z2 = []

with open('1_RM_WRITE.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(int(row[0]))
        y.append(int(row[1]))
        z.append(int(row[2]))
        
with open('M_RM_WRITE.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x2.append(int(row[0]))
        y2.append(int(row[1]))
        z2.append(int(row[2]))
        
plt.clf()
plt.plot(x,z, '-',label='1 RM')
plt.plot(x2,z2, '-',label='Multiple RM')
plt.xlim([0, 550])
plt.ylim([0, 200])
plt.xlabel('no. of transactions per second')
plt.ylabel('iterations before crash')
plt.title('Successful iterations before crash (WRITE)')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []
z = []
x2 = []
y2 = []
z2 = []


x3 = []
y3 = []
z3 = []
x4 = []
y4 = []
z4 = []

with open('1_RM_WRITE.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x3.append(int(row[0]))
        y3.append(int(row[1]))
        z3.append(int(row[2]))
        
with open('M_RM_WRITE.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x4.append(int(row[0]))
        y4.append(int(row[1]))
        z4.append(int(row[2]))

with open('1_RM_RW.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(int(row[0]))
        y.append(int(row[1]))
        z.append(int(row[2]))
        
with open('M_RM_RW.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x2.append(int(row[0]))
        y2.append(int(row[1]))
        z2.append(int(row[2]))
        
plt.clf()
plt.plot(x,z, '-',label='1 RM Read & Write')
plt.plot(x2,z2, '-',label='Multiple RM Read & Write')
plt.plot(x3,z3, '-',label='1 RM Write')
plt.plot(x4,z4, '-',label='Multiple RM Write')
plt.xlim([0, 550])
plt.ylim([0, 150])
plt.xlabel('no. of transactions per second')
plt.ylabel('iterations before crash')
plt.title('Successful iterations before crash (READ & WRITE)')
plt.legend()
plt.legend(loc=1, prop={'size': 10})
plt.show()
